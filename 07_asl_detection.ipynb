# %% [markdown]
# # asl_detection
# > putting the `hand_detection` and `training_classifier` pipeline together

# %%
import os
from asl_detection.detection.utils import draw_boxes, load_model

# %%
hand_detector_path = '/home/nic/repos/darknet/backup/asl/asl-yolov3_best.weights'
hand_detector = load_model(hand_detector_path, weights=True)
classifier_path = '/home/nic/repos/git/asl_detection/results/classification/model/model_0.h5'
classifier = load_model(classifier_path)
# Out:
# model loaded!...
# model loaded!...

# %%
files_path = '/home/nic/data/asl/imgs'
files = os.listdir(files_path)
files = [os.path.join(files_path, file) for file in files][:10]
save_dir = './results/detection'
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# - attention seems to focus around the fingers for correctly classifying `C`
# - the cropping for `N` and `K` is a little off, perhaps training
# - cropping for `D` is also off, the cropped image could either be `D` or `X` depending on whether the index finger is crooked
# - classifer seems to have trouble distinguishing between the similar letters `E` and `S` as aside from the position of the thumb, they look the same

# %%
draw_boxes(hand_detector,
           files,
           figsize=(10, 10),
           save_dir=save_dir,
           show_classes=True,
           classifier=classifier)
